# %% [markdown]
# # Identifying trends in modern Greenland temperatures using ice cores
# _A final project for Stable Isotope Geochemistry_
#
# By: George Lu and Sam Chester

# %% [markdown]
# ## 1. Introduction
# The goal of this project is to process and interpret near-present d18o data from various ice cores taken from Greenland. BACKGROUND ON ICE CORES IN GREENLAND.
#
# We are approaching our investigation from a novice's perspective. First, we look at trends between cores to identify any spatiotemporal relationships. Next, we compare the ice-core data with historical temperature observations from coastal Greenland to further establish if there's any identifiable spatiotemporal trends. Finally, we attempt to use some temperature relationships to make temperature predictions using the ice core data.
#
# The project is formatted as a Jupyter Notebook. It includes blocks of code which conduct our analysis and generates figures. Before we continue to the next section, we need to import some relevant Python libraries for our analysis. The comment at the top of each code cell describes the action done by the cell, and any outputs from the code will appear below the cell.

# %%
# Import libraries
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import glob
import os

# %% [markdown]
# ## 2. Data
# ### 2.1 Ice Cores
# The following section and its subsections describe all the ice core data we use. Each core-specific subsection describes when the core was acquired, the location of each drilling site, and what initial findings were made with the core. Accompanied with each paragraph is a plot of the core's d18o values.

# %%
# Define a plotting function for core timeseries
def plot_cores(core_list):
    fig, ax = plt.subplots(figsize=(8,4),layout='tight')
    for core in core_list:
        core.plot(ax=ax)
    return fig, ax

# %% [markdown]
# #### 2.1.1 Camp Century
# TEXT

# %%
# Load Camp century core data and plot
cc_1977 = pd.read_csv("data/campcentury/del1977.txt", sep="	",skiprows=74, names=["year", "d18o_cc1977"],dtype='float')
cc_1977 = cc_1977.set_index('year')
cc_latlon = (77.167,-61.133)

# longer series past 1700s
cc_1967 = pd.read_csv("data/campcentury/cc-1ynew.txt", sep="	",skiprows=75, names=["year", "d18o_cc1967"],dtype='float')
cc_1967 = cc_1967.set_index('year')

plot_cores([cc_1977,cc_1967])
# Out:
# (<Figure size 800x400 with 1 Axes>, <AxesSubplot:xlabel='year'>)

# %% [markdown]
# #### 2.1.2 Dye 2
# TEXT

# %%
# Load Dye 2 data and plot
dye2 = pd.read_csv("data/dye2/dye2.csv",names=["year", "d18o_dye2"],dtype='float')[:-1]
dye2 = dye2.set_index('year')
plot_cores([dye2])
# Out:
# (<Figure size 800x400 with 1 Axes>, <AxesSubplot:xlabel='year'>)

# %% [markdown]
# #### 2.1.3 Dye 3
# TEXT

# %%
# Load Dye 3 data and plot
dye3 = pd.read_csv("data/dye3/dye3-1yr.txt", sep="	",skiprows=17, names=["year", "d18o_dye3"],dtype='float')[:630]
dye3 = dye3.set_index('year')
plot_cores([dye3])
# Out:
# (<Figure size 800x400 with 1 Axes>, <AxesSubplot:xlabel='year'>)

# %% [markdown]
# #### 2.1.4 Summit
# TEXT

# %%
# Load Summit data and plot
summit = pd.read_csv("data/summit/sum74-1y.txt", sep="	",skiprows=79, names=["year", "d18o_summit"],dtype='float')
summit = summit.set_index('year')
plot_cores([summit])
# Out:
# (<Figure size 800x400 with 1 Axes>, <AxesSubplot:xlabel='year'>)

# %% [markdown]
# #### 2.1.4 NEEM
# TEXT

# %%
# Load NEEM data and plot
neem = pd.read_csv("data/neem/NEEM.csv",dtype='float').rename(columns={'d18o':'d18o_neem'})
neem = neem.set_index('year')
plot_cores([neem])
# Out:
# (<Figure size 800x400 with 1 Axes>, <AxesSubplot:xlabel='year'>)

# %% [markdown]
# #### 2.1.5 Renland
# TEXT

# %%
# Load Renland data and plot
renland = pd.read_csv("data/renland/renland.csv",dtype='float')
renland = renland.set_index('year')
plot_cores([renland])
# Out:
# (<Figure size 800x400 with 1 Axes>, <AxesSubplot:xlabel='year'>)

# %% [markdown]
# ### 2.2 Historic Temperatures
# A paragraph describing how the temperature record was taken, and a map of the temperature sites.

# %%
# load temperature data
def load_csv(folder):
    filenames = glob.glob(f"{folder}/*.csv")

    li = []

    for filename in filenames:
        df = pd.read_csv(filename, dtype='float').T
        df = df.rename_axis('year')
        name = filename.split('_')[2]
        df = df.rename(columns={0:f'T_{name}'})
        df.index = df.index.map(int)
        li.append(df)
        
    return pd.concat(li,axis=1).sort_index()
#temp_112 = pd.read_csv("data/temp_data/region_34262_out.csv",dtype='float').T
#temp_112=temp_112.rename_axis('year')
#temp_112 = temp_112.rename(columns={0:'T_112'})
#temp_112.index = temp_112.index.map(int)
test = load_csv('data/temp_data')
fig, ax = plt.subplots(figsize=(8,4),layout='tight')
test.plot(ax=ax)
plt.xlim([1700,2000])
# Out:
# (1700.0, 2000.0)

# %% [markdown]
# # 3. Identifying spatiotemporal trends in historic core data

# %% [markdown]
# Spatial map/animation?
# Plot latitude with mean d18o
# Elevation with mean d18o

# %%
fig, ax = plt.subplots(figsize=(10,4),layout='tight')
all_cores = pd.concat([cc_1977,cc_1967,dye2,dye3,summit,neem,renland],axis=1).sort_index()

all_cores.plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
corr = all_cores.corr()
corr.style.background_gradient(cmap='coolwarm',vmin=-1,vmax=1)
# Out:
# <style type="text/css">
# #T_ff133_row0_col0, #T_ff133_row1_col1, #T_ff133_row2_col2, #T_ff133_row3_col3, #T_ff133_row4_col4, #T_ff133_row5_col5, #T_ff133_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ff133_row0_col1, #T_ff133_row1_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_ff133_row0_col2, #T_ff133_row2_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_ff133_row0_col3, #T_ff133_row3_col0 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_ff133_row0_col4, #T_ff133_row4_col0 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_ff133_row0_col5, #T_ff133_row5_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_ff133_row0_col6, #T_ff133_row6_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_ff133_row1_col2, #T_ff133_row2_col1 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_ff133_row1_col3, #T_ff133_row3_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_ff133_row1_col4, #T_ff133_row2_col5, #T_ff133_row4_col1, #T_ff133_row5_col2 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_ff133_row1_col5, #T_ff133_row4_col6, #T_ff133_row5_col1, #T_ff133_row6_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_ff133_row1_col6, #T_ff133_row6_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_ff133_row2_col3, #T_ff133_row3_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ff133_row2_col4, #T_ff133_row4_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_ff133_row2_col6, #T_ff133_row6_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_ff133_row3_col4, #T_ff133_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_ff133_row3_col5, #T_ff133_row5_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_ff133_row3_col6, #T_ff133_row6_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_ff133_row4_col5, #T_ff133_row5_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_ff133_row5_col6, #T_ff133_row6_col5 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# </style>
# <table id="T_ff133">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff133_level0_col0" class="col_heading level0 col0" >d18o_cc1977</th>
#       <th id="T_ff133_level0_col1" class="col_heading level0 col1" >d18o_cc1967</th>
#       <th id="T_ff133_level0_col2" class="col_heading level0 col2" >d18o_dye2</th>
#       <th id="T_ff133_level0_col3" class="col_heading level0 col3" >d18o_dye3</th>
#       <th id="T_ff133_level0_col4" class="col_heading level0 col4" >d18o_summit</th>
#       <th id="T_ff133_level0_col5" class="col_heading level0 col5" >d18o_neem</th>
#       <th id="T_ff133_level0_col6" class="col_heading level0 col6" >d18o_renland</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff133_level0_row0" class="row_heading level0 row0" >d18o_cc1977</th>
#       <td id="T_ff133_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ff133_row0_col1" class="data row0 col1" >0.175748</td>
#       <td id="T_ff133_row0_col2" class="data row0 col2" >0.170013</td>
#       <td id="T_ff133_row0_col3" class="data row0 col3" >0.119309</td>
#       <td id="T_ff133_row0_col4" class="data row0 col4" >0.390421</td>
#       <td id="T_ff133_row0_col5" class="data row0 col5" >0.482098</td>
#       <td id="T_ff133_row0_col6" class="data row0 col6" >0.081906</td>
#     </tr>
#     <tr>
#       <th id="T_ff133_level0_row1" class="row_heading level0 row1" >d18o_cc1967</th>
#       <td id="T_ff133_row1_col0" class="data row1 col0" >0.175748</td>
#       <td id="T_ff133_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ff133_row1_col2" class="data row1 col2" >0.035251</td>
#       <td id="T_ff133_row1_col3" class="data row1 col3" >-0.096778</td>
#       <td id="T_ff133_row1_col4" class="data row1 col4" >0.159870</td>
#       <td id="T_ff133_row1_col5" class="data row1 col5" >0.232908</td>
#       <td id="T_ff133_row1_col6" class="data row1 col6" >0.027767</td>
#     </tr>
#     <tr>
#       <th id="T_ff133_level0_row2" class="row_heading level0 row2" >d18o_dye2</th>
#       <td id="T_ff133_row2_col0" class="data row2 col0" >0.170013</td>
#       <td id="T_ff133_row2_col1" class="data row2 col1" >0.035251</td>
#       <td id="T_ff133_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ff133_row2_col3" class="data row2 col3" >0.253898</td>
#       <td id="T_ff133_row2_col4" class="data row2 col4" >0.292971</td>
#       <td id="T_ff133_row2_col5" class="data row2 col5" >0.158935</td>
#       <td id="T_ff133_row2_col6" class="data row2 col6" >0.126845</td>
#     </tr>
#     <tr>
#       <th id="T_ff133_level0_row3" class="row_heading level0 row3" >d18o_dye3</th>
#       <td id="T_ff133_row3_col0" class="data row3 col0" >0.119309</td>
#       <td id="T_ff133_row3_col1" class="data row3 col1" >-0.096778</td>
#       <td id="T_ff133_row3_col2" class="data row3 col2" >0.253898</td>
#       <td id="T_ff133_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ff133_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_ff133_row3_col5" class="data row3 col5" >0.223801</td>
#       <td id="T_ff133_row3_col6" class="data row3 col6" >0.242987</td>
#     </tr>
#     <tr>
#       <th id="T_ff133_level0_row4" class="row_heading level0 row4" >d18o_summit</th>
#       <td id="T_ff133_row4_col0" class="data row4 col0" >0.390421</td>
#       <td id="T_ff133_row4_col1" class="data row4 col1" >0.159870</td>
#       <td id="T_ff133_row4_col2" class="data row4 col2" >0.292971</td>
#       <td id="T_ff133_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_ff133_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_ff133_row4_col5" class="data row4 col5" >0.314320</td>
#       <td id="T_ff133_row4_col6" class="data row4 col6" >0.228719</td>
#     </tr>
#     <tr>
#       <th id="T_ff133_level0_row5" class="row_heading level0 row5" >d18o_neem</th>
#       <td id="T_ff133_row5_col0" class="data row5 col0" >0.482098</td>
#       <td id="T_ff133_row5_col1" class="data row5 col1" >0.232908</td>
#       <td id="T_ff133_row5_col2" class="data row5 col2" >0.158935</td>
#       <td id="T_ff133_row5_col3" class="data row5 col3" >0.223801</td>
#       <td id="T_ff133_row5_col4" class="data row5 col4" >0.314320</td>
#       <td id="T_ff133_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_ff133_row5_col6" class="data row5 col6" >0.208616</td>
#     </tr>
#     <tr>
#       <th id="T_ff133_level0_row6" class="row_heading level0 row6" >d18o_renland</th>
#       <td id="T_ff133_row6_col0" class="data row6 col0" >0.081906</td>
#       <td id="T_ff133_row6_col1" class="data row6 col1" >0.027767</td>
#       <td id="T_ff133_row6_col2" class="data row6 col2" >0.126845</td>
#       <td id="T_ff133_row6_col3" class="data row6 col3" >0.242987</td>
#       <td id="T_ff133_row6_col4" class="data row6 col4" >0.228719</td>
#       <td id="T_ff133_row6_col5" class="data row6 col5" >0.208616</td>
#       <td id="T_ff133_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
test = all_cores.rolling(10).mean()
test.plot()
#plt.xlim([1800,2000])
# Out:
# <AxesSubplot:xlabel='year'>

# %%
corr = test.corr()
corr.style.background_gradient(cmap='coolwarm',vmin=-1,vmax=1)
# Out:
# <style type="text/css">
# #T_a5425_row0_col0, #T_a5425_row1_col1, #T_a5425_row2_col2, #T_a5425_row3_col3, #T_a5425_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a5425_row0_col1, #T_a5425_row1_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_a5425_row0_col2, #T_a5425_row2_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_a5425_row0_col3, #T_a5425_row3_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_a5425_row0_col4, #T_a5425_row4_col0 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_a5425_row1_col2, #T_a5425_row2_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_a5425_row1_col3, #T_a5425_row3_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_a5425_row1_col4, #T_a5425_row4_col1 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_a5425_row2_col3, #T_a5425_row3_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_a5425_row2_col4, #T_a5425_row4_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_a5425_row3_col4, #T_a5425_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a5425">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5425_level0_col0" class="col_heading level0 col0" >d18o_cc1977</th>
#       <th id="T_a5425_level0_col1" class="col_heading level0 col1" >d18o_cc1967</th>
#       <th id="T_a5425_level0_col2" class="col_heading level0 col2" >d18o_dye2</th>
#       <th id="T_a5425_level0_col3" class="col_heading level0 col3" >d18o_dye3</th>
#       <th id="T_a5425_level0_col4" class="col_heading level0 col4" >d18o_summit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5425_level0_row0" class="row_heading level0 row0" >d18o_cc1977</th>
#       <td id="T_a5425_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a5425_row0_col1" class="data row0 col1" >0.577567</td>
#       <td id="T_a5425_row0_col2" class="data row0 col2" >0.195642</td>
#       <td id="T_a5425_row0_col3" class="data row0 col3" >0.303098</td>
#       <td id="T_a5425_row0_col4" class="data row0 col4" >0.324641</td>
#     </tr>
#     <tr>
#       <th id="T_a5425_level0_row1" class="row_heading level0 row1" >d18o_cc1967</th>
#       <td id="T_a5425_row1_col0" class="data row1 col0" >0.577567</td>
#       <td id="T_a5425_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a5425_row1_col2" class="data row1 col2" >0.222866</td>
#       <td id="T_a5425_row1_col3" class="data row1 col3" >-0.091659</td>
#       <td id="T_a5425_row1_col4" class="data row1 col4" >0.236078</td>
#     </tr>
#     <tr>
#       <th id="T_a5425_level0_row2" class="row_heading level0 row2" >d18o_dye2</th>
#       <td id="T_a5425_row2_col0" class="data row2 col0" >0.195642</td>
#       <td id="T_a5425_row2_col1" class="data row2 col1" >0.222866</td>
#       <td id="T_a5425_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a5425_row2_col3" class="data row2 col3" >0.608315</td>
#       <td id="T_a5425_row2_col4" class="data row2 col4" >0.632841</td>
#     </tr>
#     <tr>
#       <th id="T_a5425_level0_row3" class="row_heading level0 row3" >d18o_dye3</th>
#       <td id="T_a5425_row3_col0" class="data row3 col0" >0.303098</td>
#       <td id="T_a5425_row3_col1" class="data row3 col1" >-0.091659</td>
#       <td id="T_a5425_row3_col2" class="data row3 col2" >0.608315</td>
#       <td id="T_a5425_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a5425_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5425_level0_row4" class="row_heading level0 row4" >d18o_summit</th>
#       <td id="T_a5425_row4_col0" class="data row4 col0" >0.324641</td>
#       <td id="T_a5425_row4_col1" class="data row4 col1" >0.236078</td>
#       <td id="T_a5425_row4_col2" class="data row4 col2" >0.632841</td>
#       <td id="T_a5425_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_a5425_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Make arrays consisting of mean temp at each site, along with elev, lon, lat. Get correlation of those.

# %% [markdown]
# ## 4. Comparing ice-core data with observations.

# %% [markdown]
# ## 5. Making predictions
